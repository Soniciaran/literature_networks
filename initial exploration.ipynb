# %%
# Data manipulation
import pandas as pd
import numpy as np
# Plotting
import matplotlib.pyplot as plt
import seaborn as sns

# Deal with paths
from pathlib import Path

# Text Processing
import re

import spacy
from spacy import displacy

# %%
dresden_path = sorted(list(Path('../datasets/dresden/Butcher, Jim').glob('**/*.txt')))

# %%
import dresden as dre

dresden = dre.load_dresden(dresden_path)

# %%
t = pd.DataFrame(dresden).T
t.head()
# Out:
#     book                                               text
# 1.1    1  1\n\nI heard the mailman approach my office do...
# 1.2    1  2\n\nKarrin Murphy was waiting for me outside ...
# 1.3    1  3\n\nGentleman Johnny Marcone didn’t look like...
# 1.4    1  4\n\nMonica No-Last-Name was standing outside ...
# 1.5    1  5\n\nMcAnally’s is a pub a few blocks from my ...

# %%
t

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp(dresden["1.1"]["text"])
sentence_spans = list(doc.sents)
displacy.render(sentence_spans, style = "ent", jupyter = True)
# Out:
# C:\Users\Ciaran\miniconda3\envs\lit_networks\lib\site-packages\spacy\displacy\__init__.py:200: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br></br>I heard the mailman approach my office door,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     half an hour earlier
# ...
